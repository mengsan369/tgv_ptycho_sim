# %% [markdown]
# # 00 Check Propagation
#
# Minimal notebook placeholder for the exp001 propagation sanity check.

# %%
from tgv_ptycho.optics.fields import make_plane_wave
from tgv_ptycho.optics.angular_spectrum import angular_spectrum_propagate

U0 = make_plane_wave((128, 128), dx=2e-6, wavelength=532e-9)
Uz = angular_spectrum_propagate(U0, dx=2e-6, wavelength=532e-9, z=0.01)
Uz.shape
